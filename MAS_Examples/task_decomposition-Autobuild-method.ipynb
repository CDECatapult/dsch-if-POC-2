# %% [markdown]
# # Task Decomposition
# # Approach 3. Use AutoBuild
#
# AutoBuild is an effective approach that dynamically and automatically generates a group of experts and use their conversation to solve a task.

# %% [markdown]
# First make sure the `pyautogen` package is installed.

# %%
! pip install -qqq "pyautogen>=0.2.18"

# %% [markdown]
# Import the relevant modules and configure the LLM.
# See [LLM Configuration](./llm_configuration) for how to configure LLMs.

# %%
import os
from datetime import datetime
from typing import Callable, Dict, Literal, Optional, Union

from typing_extensions import Annotated

from autogen import (
    Agent,
    AssistantAgent,
    ConversableAgent,
    GroupChat,
    GroupChatManager,
    UserProxyAgent,
    config_list_from_json,
    register_function,
)
from autogen.agentchat.contrib import agent_builder
from autogen.cache import Cache
from autogen.coding import DockerCommandLineCodeExecutor, LocalCommandLineCodeExecutor

os.environ["OPENAI_API_KEY"] = "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"

config_list = [
    {"model": "gpt-4-1106-preview", "api_key": os.environ["OPENAI_API_KEY"]},
    {"model": "gpt-3.5-turbo", "api_key": os.environ["OPENAI_API_KEY"]},
]
# You can also use the following method to load the config list from a file or environment variable.
# config

# config_list=[
#         {
#             "model": "NotRequired", # Loaded with LiteLLM command
#             "api_key": "NotRequired", # Not needed
#             "base_url": "http://52.56.167.144:4000",  # Your LiteLLM URL
#             "price" : [0, 0]
#         }
#     ]

llm_config={
    "config_list": config_list,
    "cache_seed": None, # Turns off caching, useful for testing different models
}

# %% [markdown]
# The task to be solved to write a blog post about the stock price performance of Nvidia in the past month.

# %%
task = (
    """
The task is to create a python code that translate from  source data model to target data model.

An example of source and target data structures are below:
source model example in json format:
    {
        "volume":177.0730798,
        "area":434.4258052,
        "length":0.0,
        "VolumeUnit":"m3",
        "Category":"CV-CV-Abutment-G-P",
        "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
        "ss_category_name":"ReadyMix",
        "Embodied_Carbon":54553.4986645559
    }

target model example translated from the example of source data model in json format:
    {
        "Name_notes":"CV-CV-Abutment-G-P",
        "Asset_Code":"9cf0bb8930ab4d3a9e8082b475796fae",
        "Quantity":177.0730798,
        "Unit":"m3",
        "Total":54553.4986645559,
        "Concrete":54553.4986645559
    }

another example:
source model example in json format:
source data model:
    {
        "volume":1.42005247,
        "area":74.7313579,
        "length":0.0,
        "VolumeUnit":"m3",
        "Category":"CV-CV-Barrier-G-P",
        "QTY":110,
        "ss_epd_id":"5e99ea4bf1124b66a0899c4e072550f4",
        "ss_category_name":"Steel",
        "Embodied_Carbon":6780.3888439634
    }
target model example translated from the example of source data model in json format:
    {
        "Name_notes":"CV-CV-Barrier-G-P",
        "Asset_Code":"5e99ea4bf1124b66a0899c4e072550f4",
        "Quantity":1.42005247,
        "Unit":"m3",
        "Total":6780.3888439634,
        "Steel":6780.3888439634,
    }

Here is the source model to be translated:

    {
        "volume":177.0730798,
        "area":434.4258052,
        "length":0.0,
        "VolumeUnit":"m3",
        "Category":"CV-CV-Abutment-G-P",
        "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
        "ss_category_name":"ReadyMix",
        "Embodied_Carbon":54553.4986645559
    }

"""
)
print(task)
# Out:
# The task is to create a python code that translate from  source data model to target data model.
#
# An example of source and target data structures are below:
# source model example in json format:
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }
#
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Abutment-G-P",
#         "Asset_Code":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "Quantity":177.0730798,
#         "Unit":"m3",
#         "Total":54553.4986645559,
#         "Concrete":54553.4986645559
#     }
#
# another example:
# source model example in json format:
# source data model:
#     {
#         "volume":1.42005247,
#         "area":74.7313579,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Barrier-G-P",
#         "QTY":110,
#         "ss_epd_id":"5e99ea4bf1124b66a0899c4e072550f4",
#         "ss_category_name":"Steel",
#         "Embodied_Carbon":6780.3888439634
#     }
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Barrier-G-P",
#         "Asset_Code":"5e99ea4bf1124b66a0899c4e072550f4",
#         "Quantity":1.42005247,
#         "Unit":"m3",
#         "Total":6780.3888439634,
#         "Steel":6780.3888439634,
#     }
#
# Here is the source model to be translated:
#
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }

# %% [markdown]
# ## Approach 3. Use AutoBuild
# [AutoBuild](https://microsoft.github.io/autogen/blog/2023/11/26/Agent-AutoBuild) is an effective approach that generates a group of experts and use their conversation to solve a task. In AutoBuild, each expert handles a part of the task, therefore effectively and comprehensively solving it.

# %%
AUTOBUILD_SYSTEM_MESSAGE = """You are a manager of a group of advanced experts, your primary objective is to delegate the resolution of tasks to other experts through structured dialogue and derive conclusive insights from their conversation summarization.
When a task is assigned, it's crucial to assess its constraints and conditions for completion. If feasible, the task should be divided into smaller, logically consistent subtasks. Following this division, you have the option to address these subtasks by forming a team of agents using the "autobuild" tool.
Upon the completion of all tasks and verifications, you should conclude the operation and reply "TERMINATE".
"""

user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    code_execution_config=False,
)

autobuild_assistant = AssistantAgent(
    name="Autobuild Assistant",
    llm_config={"config_list": config_list, "cache_seed": None},
)

import os
os.environ["OAI_CONFIG_LIST"] = """[{"model": "gpt-4-1106-preview", "api_key": "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"}]"""

def autobuild_reply(recipient, messages, sender, config):

    last_msg = messages[-1]["content"]

    builder = agent_builder.AgentBuilder(config_file_or_env="OAI_CONFIG_LIST",builder_model="gpt-4-1106-preview",agent_model="gpt-4-1106-preview")

    agent_list, agent_configs = builder.build(
        last_msg, default_llm_config={"config_list": config_list, "cache_seed": None}
    )
    # start nested chat
    nested_group_chat = GroupChat(
        agents=agent_list,
        messages=[],
    )
    manager = GroupChatManager(groupchat=nested_group_chat, llm_config={"config_list": config_list, "cache_seed": None})
    chat_res = agent_list[0].initiate_chat(
        manager, message=agent_configs.get("building_task", last_msg), summary_method="reflection_with_llm"
    )
    return True, chat_res.summary


autobuild_assistant.register_reply([Agent, None], autobuild_reply)

with Cache.disk(cache_seed=41) as cache:
    user_proxy.initiate_chat(autobuild_assistant, message=task, max_turns=1)
# Out:
# user_proxy (to Autobuild Assistant):
#
#
# The task is to create a python code that translate from  source data model to target data model.
#
# An example of source and target data structures are below:
# source model example in json format:
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }
#
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Abutment-G-P",
#         "Asset_Code":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "Quantity":177.0730798,
#         "Unit":"m3",
#         "Total":54553.4986645559,
#         "Concrete":54553.4986645559
#     }
#
# another example:
# source model example in json format:
# source data model:
#     {
#         "volume":1.42005247,
#         "area":74.7313579,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Barrier-G-P",
#         "QTY":110,
#         "ss_epd_id":"5e99ea4bf1124b66a0899c4e072550f4",
#         "ss_category_name":"Steel",
#         "Embodied_Carbon":6780.3888439634
#     }
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Barrier-G-P",
#         "Asset_Code":"5e99ea4bf1124b66a0899c4e072550f4",
#         "Quantity":1.42005247,
#         "Unit":"m3",
#         "Total":6780.3888439634,
#         "Steel":6780.3888439634,
#     }
#
# Here is the source model to be translated:
#
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }
#
#
#
# --------------------------------------------------------------------------------
# ==> Generating agents...
# ['DataModeling_Expert', 'JSON_Expert', 'Python_Expert', 'DataTransformation_Expert', 'SoftwareArchitecture_Expert'] are generated.
# ==> Generating system message...
# Preparing system message for DataModeling_Expert
# Preparing system message for JSON_Expert
# Preparing system message for Python_Expert
# Preparing system message for DataTransformation_Expert
# Preparing system message for SoftwareArchitecture_Expert
# ==> Generating description...
# Preparing description for DataModeling_Expert
# Preparing description for JSON_Expert
# Preparing description for Python_Expert
# Preparing description for DataTransformation_Expert
# Preparing description for SoftwareArchitecture_Expert
# ==> Creating agents...
# Creating agent DataModeling_Expert...
# Creating agent JSON_Expert...
# Creating agent Python_Expert...
# Creating agent DataTransformation_Expert...
# Creating agent SoftwareArchitecture_Expert...
# Adding user console proxy...
# DataModeling_Expert (to chat_manager):
#
#
# The task is to create a python code that translate from  source data model to target data model.
#
# An example of source and target data structures are below:
# source model example in json format:
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }
#
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Abutment-G-P",
#         "Asset_Code":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "Quantity":177.0730798,
#         "Unit":"m3",
#         "Total":54553.4986645559,
#         "Concrete":54553.4986645559
#     }
#
# another example:
# source model example in json format:
# source data model:
#     {
#         "volume":1.42005247,
#         "area":74.7313579,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Barrier-G-P",
#         "QTY":110,
#         "ss_epd_id":"5e99ea4bf1124b66a0899c4e072550f4",
#         "ss_category_name":"Steel",
#         "Embodied_Carbon":6780.3888439634
#     }
# target model example translated from the example of source data model in json format:
#     {
#         "Name_notes":"CV-CV-Barrier-G-P",
#         "Asset_Code":"5e99ea4bf1124b66a0899c4e072550f4",
#         "Quantity":1.42005247,
#         "Unit":"m3",
#         "Total":6780.3888439634,
#         "Steel":6780.3888439634,
#     }
#
# Here is the source model to be translated:
#
#     {
#         "volume":177.0730798,
#         "area":434.4258052,
#         "length":0.0,
#         "VolumeUnit":"m3",
#         "Category":"CV-CV-Abutment-G-P",
#         "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#         "ss_category_name":"ReadyMix",
#         "Embodied_Carbon":54553.4986645559
#     }
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Python_Expert
#
# Python_Expert (to chat_manager):
#
# To translate the provided source JSON object into the target data model format, consider the following Python code snippet:
#
# ```python
# import json
#
# def translate_model(source_json):
#     source_data = json.loads(source_json)
#
#     # Needed to match the expected model's field for the material type (e.g., "Concrete")
#     material_type = ""
#     if source_data["ss_category_name"] == "ReadyMix":
#         material_type = "Concrete"
#     elif source_data["ss_category_name"] == "Steel":
#         material_type = "Steel"
#     else:
#         # Assuming other types are not part of the example provided
#         # Could be extended to handle other mappings as required
#         material_type = source_Material Type_MAPPING.get(source_data["ss_category_name"], "Other")
#
#     target_model = {
#         "Name_notes": source_data["Category"],
#         "Asset_Code": source_data["ss_epd_id"],
#         "Quantity": source_data["volume"],
#         "Unit": source_data["VolumeUnit"],
#         "Total": source_data["Embodied_Carbon"],
#         material_type: source_data["Embodied_Carbon"]
#     }
#
#     return json.dumps(target_model, indent=4)
#
# # Source JSON string to be converted
# source_json = '''{
#     "volume":177.0730798,
#     "area":434.4258052,
#     "length":0.0,
#     "VolumeUnit":"m3",
#     "Category":"CV-CV-Abutment-G-P",
#     "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#     "ss_category_name":"ReadyMix",
#     "Embodied_Carbon":54553.4986645559
# }'''
#
# # Call the function and print the result
# translated_json = translate_model(source_json)
# print(translated_json)
# ```
#
# The function `translate_model` takes in a JSON string representing the source model, parses this into a Python dictionary, then creates a new dictionary following the target model format. If the material is "ReadyMix," it is translated to "Concrete" in the target model, and "Steel" remains the same. Other types are not explicitly handled in the provided examples, but you could create a mapping for additional source material types to their corresponding target values if necessary.
#
# Shall we proceed to execute this code to verify the output?
#
# --------------------------------------------------------------------------------
#
# Next speaker: Computer_terminal
#
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# Computer_terminal (to chat_manager):
#
# exitcode: 1 (execution failed)
# Code output:
#   File "", line 15
#     material_type = source_Material Type_MAPPING.get(source_data["ss_category_name"], "Other")
#                                     ^^^^^^^^^^^^
# SyntaxError: invalid syntax
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Python_Expert
#
# Python_Expert (to chat_manager):
#
# It seems there was a syntax error in the code snippet due to an incorrectly named variable `source_Material Type_MAPPING`, which is not previously defined and does not follow proper variable naming conventions in Python. Let me correct this and provide you with a fixed code snippet to run:
#
# ```python
# import json
#
# def translate_model(source_json):
#     source_data = json.loads(source_json)
#
#     # Creating a mapping for different material types
#     material_mapping = {"ReadyMix": "Concrete", "Steel": "Steel"}
#     material_type = material_mapping.get(source_data["ss_category_name"], "Other")
#
#     target_model = {
#         "Name_notes": source_data["Category"],
#         "Asset_Code": source_data["ss_epd_id"],
#         "Quantity": source_data["volume"],
#         "Unit": source_data["VolumeUnit"],
#         "Total": source_data["Embodied_Carbon"],
#         material_type: source_data["Embodied_Carbon"]
#     }
#
#     return json.dumps(target_model, indent=4)
#
# # Source JSON string to be converted
# source_json = '''{
#     "volume":177.0730798,
#     "area":434.4258052,
#     "length":0.0,
#     "VolumeInternal.Unit":"m3",
#     "Category":"CV-CV-Abutment-G-P",
#     "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#     "ss_category_name":"ReadyMix",
#     "Embodied_Carbon":54553.4986645559
# }'''
#
# # Call the function and print the result
# translated_json = translate_model(source_json)
# print(translated_json)
# ```
#
# Let's run this corrected code to verify the output.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Computer_terminal
#
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# Computer_terminal (to chat_manager):
#
# exitcode: 1 (execution failed)
# Code output:
# Traceback (most recent call last):
#   File "", line 34, in <module>
#     translated_json = translate_model(source_json)
#   File "", line 14, in translate_model
#     "Unit": source_data["VolumeUnit"],
# KeyError: 'VolumeUnit'
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Python_Expert
#
# Python_Expert (to chat_manager):
#
# It looks like there was a mismatch in the key for the 'Unit' field. The source JSON string has "VolumeInternal.Unit" instead of "VolumeUnit". I'll fix the code accordingly and provide the correct code snippet:
#
# ```python
# import json
#
# def translate_model(source_json):
#     source_data = json.loads(source_json)
#
#     # Creating a mapping for different material types
#     material_mapping = {"ReadyMix": "Concrete", "Steel": "Steel"}
#     material_type = material_mapping.get(source_data["ss_category_name"], "Other")
#
#     target_model = {
#       "Name_notes": source_data["Category"],
#       "Asset_Code": source_data["ss_epd_id"],
#       "Quantity": source_data["volume"],
#       "Unit": source_data["VolumeUnit"],
#       "Total": source_data["Embodied_Carbon"],
#       material_type: source_data["Embodied_Carbon"]
#     }
#
#     return json.dumps(target_model, indent=4)
#
# # Source JSON string to be converted
# source_json = '''{
#     "volume":177.0730798,
#     "area":434.4258052,
#     "length":0.0,
#     "VolumeUnit":"m3",
#     "Category":"CV-CV-Abutment-G-P",
#     "ss_epd_id":"9cf0bb8930ab4d3a9e8082b475796fae",
#     "ss_category_name":"ReadyMix",
#     "Embodied_Carbon":54553.4986645559
# }'''
#
# # Call the function and print the result
# translated_json = translate_model(source_json)
# print(translated_json)
# ```
#
# Please execute the corrected code to verify the correct structure and data translations.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Computer_terminal
#
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# Computer_terminal (to chat_manager):
#
# exitcode: 0 (execution succeeded)
# Code output:
# {
#     "Name_notes": "CV-CV-Abutment-G-P",
#     "Asset_Code": "9cf0bb8930ab4d3a9e8082b475796fae",
#     "Quantity": 177.0730798,
#     "Unit": "m3",
#     "Total": 54553.4986645559,
#     "Concrete": 54553.4986645559
# }
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: JSON_Expert
#
# JSON_Expert (to chat_manager):
#
# The execution succeeded, and the output matches the target JSON structure we aimed for, with the "Category" translated to "Name_notes", "ss_epd_id" to "Asset_Code", the "volume" is now "Quantity", "VolumeUnit" to "Unit", and "Embodied_Carbon" to both "Total" and "Concrete", which is the corresponding material type from "ReadyMix".
#
# JSON_Expert, could you confirm that the output is correctly structured according to the JSON standards? If everything is correct, we should verify with test cases to ensure the functionality of the translation code.
#
# --------------------------------------------------------------------------------
#
# Next speaker: JSON_Expert
#
# JSON_Expert (to chat_manager):
#
# The JSON output structure seems to be correct according to JSON standards:
#
# - Keys and string values are wrapped in double quotes.
# - Numeric values for "Quantity" and "Embodied_Carbon" are correctly displayed without quotes.
# - Colon (:) is used to separate keys and values.
# - Comma (,) is used to separate key-value pairs.
#
# The output JSON is:
#
# ```json
# {
#     "Name_notes": "CV-CV-Abutment-G-P",
#     "Asset_Code": "9cf0bb8930ab4d3a9e8082b475796fae",
#     "Quantity": 177.0730798,
#     "Unit": "m3",
#     "Total": 54553.4986645559,
#     "Concrete": 54553.4986645559
# }
# ```
#
# However, the code should also be able to handle the other case where `"ss_category_name": "Steel"`, translating to a `"Steel"` key in the target model.
#
# DataTransformation_Expert, could you devise appropriate test cases that reflect different potential values of "ss_category_name" and other edge cases to ensure the robustness of the script? After verifying the test cases, we can conclude the task if everything works as expected.
#
# --------------------------------------------------------------------------------
#
# Next speaker: DataTransformation_Expert
#
# DataTransformation_Expert (to chat_manager):
#
# Certainly. To verify the robustness of the translation script, we should test it with various scenarios, including different values for `ss_category_name` and edge cases such as unexpected input formats or missing fields. Here are a few test cases:
#
# 1. Test Case with `"ss_category_ibname": "ReadyMix"`:
# ```json
# {
#     "volume": 150.0,
#     "VolumeUnit": "m3",
#     "Category": "Example-CV-P",
#     "ss_epd_id": "exampleid123456",
#     "ss_category_name": "ReadyMix",
#     "Embodied_Carbon": 32000.0
# }
# ```
# Expected "Concrete" key in the output.
#
# 2. Test Case with `"ss_category_name": "Steel"`:
# ```json
# {
#     "volume": 200.0,
#     "VolumeUnit": "ton",
#     "Category": "Example-CV-S",
#     "ss_epd_id": "exampleid789101",
#     "ss_category_name": "Steel",
#     "Embodied_Carbon": 48000.0
# }
# ```
# Expected "Steel" key in the output.
#
# 3. Test Case with an unknown value for `"ss_category_name"`:
# ```json
# {
#     "volume": 300.0,
#     "VolumeUnit": "cm3",
#     "Category": "Example-CV-X",
#     "ss_epd_id": "exampleid111213",
#     "ss_category_name": "Glass",
#     "Embodied_Carbon": 25000.0
# }
# ```
# Expected "Other" key in the output for unspecified material types.
#
# 4. Test Case with missing `"ss_category_name"` field:
# ```json
# {
#     "volume": 400.0,
#     "VolumeUnit": "m3",
#     "Category": "Example-CV-Missing",
#     "ss_epd_id": "exampleid141516",
#     "Embodied_Carbon": 15000.0
# }
# ```
# Should handle the case gracefully, either by using an "Other" key or by throwing an informative error.
#
# 5. Test Case with incorrect types, like a string for the `"volume"`:
# ```json
# {
#     "volume": "five hundred",
#     "VolumeUnit": "m3",
#     "Category": "Example-CV-T",
#     "ss_epd_id": "exampleid171819",
#     "ss_category_name": "Concrete",
#     "Embodied_Carbon": 50000.0
# }
# ```
# Should throw an informative error since "volume" is expected to be numeric.
#
# Once these test cases have been created, I'll implement them as Python test functions and conduct the tests to ensure that our script can handle each scenario appropriately. Python_Expert, could you update the script to accommodate these tests? Afterward, I'll provide the code for testing.
#
# --------------------------------------------------------------------------------
# Autobuild Assistant (to user_proxy):
#
# The provided Python script successfully translates a source JSON object into a target data model format by mapping certain source fields to new keys in the target model. The correct output structure adheres to JSON standards, and additional test cases have been proposed to ensure the translation script's robustness and ability to handle various scenarios, including different `ss_category_name` values, missing fields, and incorrect data types. The proposed script needs to be adjusted to accommodate these tests and properly handle edge cases.
#
# --------------------------------------------------------------------------------
